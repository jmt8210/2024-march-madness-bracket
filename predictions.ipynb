# %% [markdown]
# # Data Wrangling

# %%
from io import StringIO
import requests
import pandas as pd
from bs4 import BeautifulSoup

# Options to display more/less rows in output
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_rows', 60)

# Past data (in csv)
team_stats = pd.read_csv(f'./data/cbb.csv')


# Fill empty values (teams didn't make tournament)
team_stats['POSTSEASON'] = team_stats['POSTSEASON'].fillna('NIT')
team_stats['SEED'] = team_stats['SEED'].fillna(-1)
team_stats_save_team_conf = team_stats.copy()

# Encode strings into numerical values for classifier
# Store team names/conferences as dictionary mapping to integers (numbers needed for RandomForest)
team_dict = {}
conf_dict = {}
def getFromDict(x, dict):
    if x not in dict:
        dict[x] = len(dict)
    return dict[x]
team_stats['TEAM'] = team_stats['TEAM'].apply(lambda x: getFromDict(x, team_dict))
team_stats['CONF'] = team_stats['CONF'].apply(lambda x: getFromDict(x, conf_dict))


# Current data, scrape data from barttorvik.com and read into dataframe
soup = BeautifulSoup(requests.get('https://barttorvik.com/trank.php#').content, "html.parser")
# Spans contain extra data, they can be removed:
for data in soup(['span']):
    data.decompose()
df = pd.read_html(StringIO(str(soup.find("table"))), header=1)[0]

# Remove header rows, match columns and merge into existing dataframe (there's probably an easier way to get columns to match, oh well 🤷‍♂️)
stats_24 = df[df['Rk'] != 'Rk'].drop(['Rk', '3PR', '3PRD'], axis=1).rename(columns={"EFG%": "EFG_O", "EFGD%": "EFG_D", "2P%": "2P_O", "2P%D": "2P_D", "3P%": "3P_O", "3P%D": "3P_D", "Adj T.": "ADJ_T", "Rec": "W"})
stats_24 = stats_24.replace('^(\d+)-(\d+)', r'\1', regex=True).replace('\+', '', regex=True)
stats_24.columns = map(str.upper, stats_24.columns)

# Set seed (fill with n/a) and year (2024)
stats_24['SEED'] = -1
stats_24['YEAR'] = 2024
stats_24_save_team_conf = stats_24.copy()

# Use previously calculated team and conference values using dictionary
stats_24['TEAM'] = stats_24['TEAM'].apply(lambda x: getFromDict(x, team_dict))
stats_24['CONF'] = stats_24['CONF'].apply(lambda x: getFromDict(x, conf_dict))

team_stats
# Out:
#       TEAM  CONF   G   W  ADJOE  ADJDE  BARTHAG  EFG_O  EFG_D   TOR  ...  \
# 0        0     0  40  33  123.3   94.9   0.9531   52.6   48.1  15.4  ...
# 1        1     1  40  36  129.1   93.6   0.9758   54.8   47.7  12.4  ...
# 2        2     1  40  33  114.4   90.4   0.9375   53.9   47.7  14.0  ...
# 3        3     2  38  31  115.2   85.2   0.9696   53.5   43.0  17.7  ...
# 4        4     3  39  37  117.8   86.3   0.9728   56.6   41.1  16.2  ...
# ...    ...   ...  ..  ..    ...    ...      ...    ...    ...   ...  ...
# 3518   196    21  34  27  119.9  109.6   0.7369   56.3   52.9  13.6  ...
# 3519   117    11  33  27  111.4   97.3   0.8246   55.5   49.3  16.0  ...
# 3520   342    32  34  28  107.1   94.6   0.8065   51.7   44.0  19.3  ...
# 3521   157    16  38  29  112.4   97.0   0.8453   50.3   47.3  17.3  ...
# 3522   150    16  36  31  110.0   93.8   0.8622   51.2   44.5  19.8  ...
#
#       FTRD  2P_O  2P_D  3P_O  3P_D  ADJ_T   WAB  POSTSEASON  SEED  YEAR
# 0     30.4  53.9  44.6  32.7  36.2   71.7   8.6         2ND   1.0  2016
# 1     22.4  54.8  44.7  36.5  37.5   59.3  11.3         2ND   1.0  2015
# 2     30.0  54.7  46.8  35.2  33.2   65.9   6.9         2ND   3.0  2018
# 3     36.6  52.8  41.9  36.5  29.7   67.5   7.0         2ND   3.0  2019
# 4     26.9  56.3  40.0  38.2  29.0   71.5   7.7         2ND   1.0  2017
# ...    ...   ...   ...   ...   ...    ...   ...         ...   ...   ...
# 3518  27.5  54.6  52.1  39.7  36.1   69.5  -1.2         NIT  -1.0  2023
# 3519  27.8  56.4  48.6  36.4  33.6   64.4  -2.0         NIT  -1.0  2023
# 3520  28.7  52.5  42.8  33.4  31.1   69.8  -0.3         NIT  -1.0  2023
# 3521  28.9  48.8  47.2  35.6  31.6   70.7  -0.5         NIT  -1.0  2023
# 3522  40.2  49.6  44.2  35.7  30.1   58.7   1.1         NIT  -1.0  2023
#
# [3523 rows x 24 columns]

# %% [markdown]
# # Create Train/Test Data and Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# Split train/test
X = team_stats.drop('POSTSEASON', axis=1)
y = team_stats['POSTSEASON']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf = RandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Analyze Classifier Performance

# %%
from sklearn.metrics import accuracy_score

y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9177304964539007

# %% [markdown]
# # Predict 2024 March Madness
#
# Using the same process to make the classifier above, we can fit using all previous years data and predict against values in the `stats_2024` variable. We can then use the predicted `POSTSEASON` value for each team to determine the winner of each matchup (using the probability as the tiebreaker).

# %%
clf.fit(X, y)

# Find most likely POSTSEASON outcome, returning the team name, the outcome and its probability 
def getClassAndProb(x, idx):
  max_prob = 0
  max_idx = -1
  for i in range(len(x)):
    if x[i] > max_prob:
      max_prob = x[i]
      max_idx = i
  return [stats_24_save_team_conf.iloc[idx]['TEAM'], clf.classes_[max_idx], max_prob]

[getClassAndProb(x, i) for i,x in enumerate(clf.predict_proba(stats_24))]
# Out:
# [['Houston', 'NIT', 0.51],
#  ['Connecticut', 'NIT', 0.53],
#  ['Purdue', 'NIT', 0.53],
#  ['Auburn', 'NIT', 0.54],
#  ['Arizona', 'NIT', 0.52],
#  ['Iowa St.', 'NIT', 0.59],
#  ['Tennessee', 'NIT', 0.56],
#  ['North Carolina', 'NIT', 0.55],
#  ['Marquette', 'NIT', 0.51],
#  ['Creighton', 'NIT', 0.5],
#  ['Duke', 'NIT', 0.56],
#  ['Illinois', 'NIT', 0.59],
#  ["Saint Mary's", 'NIT', 0.54],
#  ['Alabama', 'NIT', 0.53],
#  ['Baylor', 'NIT', 0.52],
#  ['Gonzaga', 'NIT', 0.55],
#  ['Kansas', 'NIT', 0.62],
#  ['BYU', 'NIT', 0.65],
#  ['Texas', 'NIT', 0.61],
#  ["St. John's", 'NIT', 0.68],
#  ['Wisconsin', 'NIT', 0.66],
#  ['Michigan St.', 'NIT', 0.73],
#  ['Florida', 'NIT', 0.64],
#  ['Kentucky', 'NIT', 0.58],
#  ['Nebraska', 'NIT', 0.63],
#  ['Colorado', 'NIT', 0.61],
#  ['Texas Tech', 'NIT', 0.66],
#  ['New Mexico', 'NIT', 0.74],
#  ['San Diego St.', 'NIT', 0.68],
#  ['Mississippi St.', 'NIT', 0.7],
#  ['Northwestern', 'NIT', 0.66],
#  ['Villanova', 'NIT', 0.89],
#  ['TCU', 'NIT', 0.69],
#  ['Wake Forest', 'NIT', 0.94],
#  ['Clemson', 'NIT', 0.67],
#  ['Nevada', 'NIT', 0.66],
#  ['Ohio St.', 'NIT', 0.85],
#  ['Pittsburgh', 'NIT', 0.78],
#  ['Washington St.', 'NIT', 0.69],
#  ['Dayton', 'NIT', 0.67],
#  ['Colorado St.', 'NIT', 0.62],
#  ['Boise St.', 'NIT', 0.71],
#  ['Cincinnati', 'NIT', 0.92],
#  ['Indiana St.', 'NIT', 0.66],
#  ['Texas A&M', 'NIT', 0.69],
#  ['Oklahoma', 'NIT', 0.75],
#  ['South Carolina', 'NIT', 0.65],
#  ['Utah', 'NIT', 0.95],
#  ['Drake', 'NIT', 0.67],
#  ['Iowa', 'NIT', 0.93],
#  ['Florida Atlantic', 'NIT', 0.68],
#  ['Seton Hall', 'NIT', 0.75],
#  ['Utah St.', 'NIT', 0.67],
#  ['Virginia', 'NIT', 0.78],
#  ['Providence', 'NIT', 0.79],
#  ['Butler', 'NIT', 0.96],
#  ['Virginia Tech', 'NIT', 0.99],
#  ['UCF', 'NIT', 0.99],
#  ['Bradley', 'NIT', 0.93],
#  ['Washington', 'NIT', 0.98],
#  ['Xavier', 'NIT', 0.99],
#  ['Oregon', 'NIT', 0.9],
#  ['Kansas St.', 'NIT', 0.87],
#  ['Maryland', 'NIT', 1.0],
#  ['North Texas', 'NIT', 0.95],
#  ['UNLV', 'NIT', 0.96],
#  ['James Madison', 'NIT', 0.76],
#  ['SMU', 'NIT', 0.94],
#  ['North Carolina St.', 'NIT', 0.95],
#  ['San Francisco', 'NIT', 0.91],
#  ['Grand Canyon', 'NIT', 0.8],
#  ['Penn St.', 'NIT', 1.0],
#  ['Indiana', 'NIT', 0.85],
#  ['USC', 'NIT', 1.0],
#  ['Minnesota', 'NIT', 0.99],
#  ['Princeton', 'NIT', 0.69],
#  ['Richmond', 'NIT', 0.88],
#  ['Mississippi', 'NIT', 0.94],
#  ['Georgia', 'NIT', 0.99],
#  ['McNeese St.', 'NIT', 0.65],
#  ['VCU', 'NIT', 0.97],
#  ['Syracuse', 'NIT', 0.95],
#  ['LSU', 'NIT', 0.99],
#  ['UC Irvine', 'NIT', 0.96],
#  ['Loyola Chicago', 'NIT', 0.96],
#  ['South Florida', 'NIT', 0.88],
#  ['Boston College', 'NIT', 0.97],
#  ['Yale', 'NIT', 0.97],
#  ['Duquesne', 'NIT', 1.0],
#  ['Florida St.', 'NIT', 1.0],
#  ['Samford', 'NIT', 0.73],
#  ['UCLA', 'NIT', 1.0],
#  ['Louisiana Tech', 'NIT', 0.99],
#  ['Miami FL', 'NIT', 0.99],
#  ["Saint Joseph's", 'NIT', 0.99],
#  ['Massachusetts', 'NIT', 0.97],
#  ['Memphis', 'NIT', 0.98],
#  ['George Mason', 'NIT', 0.98],
#  ['Appalachian St.', 'NIT', 0.93],
#  ['College of Charleston', 'NIT', 0.95],
#  ['St. Bonaventure', 'NIT', 0.98],
#  ['Charlotte', 'NIT', 0.94],
#  ['Stanford', 'NIT', 0.98],
#  ['Rutgers', 'NIT', 1.0],
#  ['Belmont', 'NIT', 0.98],
#  ['Cornell', 'NIT', 0.91],
#  ['Oklahoma St.', 'NIT', 1.0],
#  ['Arkansas', 'NIT', 1.0],
#  ['Northern Iowa', 'NIT', 0.99],
#  ['Vermont', 'NIT', 0.92],
#  ['Hofstra', 'NIT', 0.96],
#  ['Western Carolina', 'NIT', 0.98],
#  ['UT Arlington', 'NIT', 1.0],
#  ['Michigan', 'NIT', 1.0],
#  ['Southern Illinois', 'NIT', 0.96],
#  ['California', 'NIT', 1.0],
#  ['Davidson', 'NIT', 1.0],
#  ['Troy', 'NIT', 0.97],
#  ['UAB', 'NIT', 0.99],
#  ['Santa Clara', 'NIT', 0.99],
#  ['UNC Wilmington', 'NIT', 0.99],
#  ['High Point', 'NIT', 0.94],
#  ['UC San Diego', 'NIT', 0.97],
#  ['Drexel', 'NIT', 0.97],
#  ['Georgia Tech', 'NIT', 1.0],
#  ['Akron', 'NIT', 0.95],
#  ['West Virginia', 'NIT', 1.0],
#  ['Arizona St.', 'NIT', 1.0],
#  ['Notre Dame', 'NIT', 1.0],
#  ['Seattle', 'NIT', 0.99],
#  ['Sam Houston St.', 'NIT', 0.96],
#  ['Morehead St.', 'NIT', 0.89],
#  ['Western Kentucky', 'NIT', 1.0],
#  ['Oakland', 'NIT', 0.97],
#  ['Wichita St.', 'NIT', 1.0],
#  ['Arkansas St.', 'NIT', 0.99],
#  ['South Dakota St.', 'NIT', 1.0],
#  ['Missouri', 'NIT', 1.0],
#  ['Youngstown St.', 'NIT', 0.97],
#  ['Louisiana Lafayette', 'NIT', 0.99],
#  ['UNC Greensboro', 'NIT', 0.99],
#  ['Towson', 'NIT', 0.98],
#  ['St. Thomas', 'NIT', 0.99],
#  ['Toledo', 'NIT', 0.99],
#  ['Ohio', 'NIT', 0.98],
#  ['Missouri St.', 'NIT', 1.0],
#  ['Liberty', 'NIT', 0.99],
#  ['Tulane', 'NIT', 0.98],
#  ['Tarleton St.', 'NIT', 0.96],
#  ['Wright St.', 'NIT', 0.97],
#  ['Murray St.', 'NIT', 0.99],
#  ['Oregon St.', 'NIT', 1.0],
#  ['Chattanooga', 'NIT', 0.98],
#  ['Wyoming', 'NIT', 1.0],
#  ['Furman', 'NIT', 0.99],
#  ['Montana', 'NIT', 0.95],
#  ['Delaware', 'NIT', 1.0],
#  ['Colgate', 'NIT', 0.96],
#  ['Quinnipiac', 'NIT', 0.96],
#  ['UTEP', 'NIT', 0.99],
#  ['Stony Brook', 'NIT', 0.96],
#  ['Weber St.', 'NIT', 0.99],
#  ['UC Davis', 'NIT', 1.0],
#  ['Eastern Washington', 'NIT', 0.98],
#  ['Winthrop', 'NIT', 0.99],
#  ['East Carolina', 'NIT', 1.0],
#  ['UMass Lowell', 'NIT', 0.95],
#  ['UNC Asheville', 'NIT', 0.99],
#  ['Hawaii', 'NIT', 0.99],
#  ['Bryant', 'NIT', 0.99],
#  ['Texas A&M Corpus Chris', 'NIT', 1.0],
#  ['Longwood', 'NIT', 0.97],
#  ['Little Rock', 'NIT', 0.98],
#  ['La Salle', 'NIT', 1.0],
#  ['Kent St.', 'NIT', 1.0],
#  ['Fort Wayne', 'NIT', 0.98],
#  ['Saint Louis', 'NIT', 1.0],
#  ['Georgetown', 'NIT', 1.0],
#  ['Illinois Chicago', 'NIT', 1.0],
#  ['Utah Valley', 'NIT', 0.99],
#  ['Fordham', 'NIT', 1.0],
#  ['Loyola Marymount', 'NIT', 1.0],
#  ['Fairfield', 'NIT', 1.0],
#  ['East Tennessee St.', 'NIT', 0.98],
#  ['Rice', 'NIT', 1.0],
#  ['Vanderbilt', 'NIT', 1.0],
#  ['Temple', 'NIT', 1.0],
#  ['Stephen F. Austin', 'NIT', 0.99],
#  ['Gardner Webb', 'NIT', 1.0],
#  ['Pepperdine', 'NIT', 1.0],
#  ['UMKC', 'NIT', 0.99],
#  ['Brown', 'NIT', 1.0],
#  ['Monmouth', 'NIT', 1.0],
#  ['Eastern Kentucky', 'NIT', 0.97],
#  ['Illinois St.', 'NIT', 1.0],
#  ['Penn', 'NIT', 1.0],
#  ['Rhode Island', 'NIT', 1.0],
#  ['Louisville', 'NIT', 1.0],
#  ['Northern Kentucky', 'NIT', 1.0],
#  ['Texas St.', 'NIT', 1.0],
#  ['Columbia', 'NIT', 1.0],
#  ['Montana St.', 'NIT', 1.0],
#  ['George Washington', 'NIT', 1.0],
#  ['Tulsa', 'NIT', 1.0],
#  ['Northern Colorado', 'NIT', 1.0],
#  ['Cleveland St.', 'NIT', 1.0],
#  ['Long Beach St.', 'NIT', 1.0],
#  ['Radford', 'NIT', 0.99],
#  ["Saint Peter's", 'NIT', 0.95],
#  ['Northeastern', 'NIT', 1.0],
#  ['Jacksonville St.', 'NIT', 1.0],
#  ['Harvard', 'NIT', 0.99],
#  ['Mercer', 'NIT', 1.0],
#  ['Abilene Christian', 'NIT', 0.99],
#  ['Evansville', 'NIT', 1.0],
#  ['Marist', 'NIT', 0.99],
#  ['Lipscomb', 'NIT', 0.94],
#  ['Rider', 'NIT', 1.0],
#  ['UC Riverside', 'NIT', 1.0],
#  ['San Jose St.', 'NIT', 1.0],
#  ['North Dakota', 'NIT', 1.0],
#  ['South Alabama', 'NIT', 1.0],
#  ['Wofford', 'NIT', 1.0],
#  ['Merrimack', 'NIT', 0.97],
#  ["Mount St. Mary's", 'NIT', 1.0],
#  ['Cal Baptist', 'NIT', 1.0],
#  ['Iona', 'NIT', 1.0],
#  ['Cal St. Fullerton', 'NIT', 1.0],
#  ['Georgia St.', 'NIT', 0.99],
#  ['Stetson', 'NIT', 0.97],
#  ['Air Force', 'NIT', 1.0],
#  ['Tennessee Martin', 'NIT', 0.99],
#  ['Fresno St.', 'NIT', 1.0],
#  ['Bowling Green', 'NIT', 0.98],
#  ['North Florida', 'NIT', 1.0],
#  ['Nicholls St.', 'NIT', 0.99],
#  ['Florida Gulf Coast', 'NIT', 1.0],
#  ['UTSA', 'NIT', 1.0],
#  ['Lamar', 'NIT', 1.0],
#  ['UC Santa Barbara', 'NIT', 1.0],
#  ['Marshall', 'NIT', 1.0],
#  ['Austin Peay', 'NIT', 0.98],
#  ['Milwaukee', 'NIT', 0.97],
#  ['Cal St. Northridge', 'NIT', 0.97],
#  ['Portland St.', 'NIT', 1.0],
#  ['Miami OH', 'NIT', 0.99],
#  ['Cal St. Bakersfield', 'NIT', 0.99],
#  ['San Diego', 'NIT', 1.0],
#  ['Idaho St.', 'NIT', 1.0],
#  ['Maine', 'NIT', 1.0],
#  ['Norfolk St.', 'NIT', 0.99],
#  ['Albany', 'NIT', 1.0],
#  ['North Carolina Central', 'NIT', 0.98],
#  ['Southern', 'NIT', 0.99],
#  ['UMBC', 'NIT', 1.0],
#  ['Queens', 'NIT', 1.0],
#  ['Southern Miss', 'NIT', 1.0],
#  ['Southern Utah', 'NIT', 1.0],
#  ['Green Bay', 'NIT', 0.98],
#  ['Canisius', 'NIT', 1.0],
#  ['Ball St.', 'NIT', 1.0],
#  ['North Dakota St.', 'NIT', 1.0],
#  ['Western Illinois', 'NIT', 0.97],
#  ['North Alabama', 'NIT', 1.0],
#  ['Central Michigan', 'NIT', 0.99],
#  ['Nebraska Omaha', 'NIT', 1.0],
#  ['Bucknell', 'NIT', 1.0],
#  ['Middle Tennessee', 'NIT', 1.0],
#  ['Georgia Southern', 'NIT', 1.0],
#  ['Lehigh', 'NIT', 1.0],
#  ['Howard', 'NIT', 1.0],
#  ['Texas Southern', 'NIT', 0.98],
#  ['Binghamton', 'NIT', 1.0],
#  ['Portland', 'NIT', 1.0],
#  ['Central Connecticut', 'NIT', 0.99],
#  ['Kennesaw St.', 'NIT', 0.99],
#  ['Oral Roberts', 'NIT', 1.0],
#  ['Utah Tech', 'NIT', 0.99],
#  ['New Mexico St.', 'NIT', 1.0],
#  ['New Hampshire', 'NIT', 1.0],
#  ['Niagara', 'NIT', 1.0],
#  ['USC Upstate', 'NIT', 1.0],
#  ['Denver', 'NIT', 1.0],
#  ['Presbyterian', 'NIT', 1.0],
#  ['The Citadel', 'NIT', 1.0],
#  ['Grambling St.', 'NIT', 0.95],
#  ['SIU Edwardsville', 'NIT', 1.0],
#  ['Louisiana Monroe', 'NIT', 1.0],
#  ['FIU', 'NIT', 1.0],
#  ['Wagner', 'NIT', 0.99],
#  ['Old Dominion', 'NIT', 1.0],
#  ['American', 'NIT', 1.0],
#  ['Sacred Heart', 'NIT', 0.99],
#  ['Boston University', 'NIT', 1.0],
#  ['Tennessee St.', 'NIT', 1.0],
#  ['DePaul', 'NIT', 1.0],
#  ['Valparaiso', 'NIT', 1.0],
#  ['South Carolina St.', 'NIT', 1.0],
#  ['Jacksonville', 'NIT', 1.0],
#  ['Alcorn St.', 'NIT', 1.0],
#  ['Bellarmine', 'NIT', 1.0],
#  ['Campbell', 'NIT', 1.0],
#  ['Northern Illinois', 'NIT', 1.0],
#  ['Chicago St.', 'NIT', 0.98],
#  ['Delaware St.', 'NIT', 1.0],
#  ['Southeastern Louisiana', 'NIT', 1.0],
#  ['Le Moyne', 'NIT', 0.99],
#  ['Jackson St.', 'NIT', 1.0],
#  ['Sacramento St.', 'NIT', 1.0],
#  ['Elon', 'NIT', 1.0],
#  ['Idaho', 'NIT', 1.0],
#  ['William & Mary', 'NIT', 1.0],
#  ['Bethune Cookman', 'NIT', 0.99],
#  ['Coastal Carolina', 'NIT', 1.0],
#  ['South Dakota', 'NIT', 1.0],
#  ['Robert Morris', 'NIT', 1.0],
#  ['Western Michigan', 'NIT', 1.0],
#  ['Northern Arizona', 'NIT', 1.0],
#  ['Northwestern St.', 'NIT', 1.0],
#  ['Eastern Illinois', 'NIT', 1.0],
#  ['Charleston Southern', 'NIT', 1.0],
#  ['Lafayette', 'NIT', 0.99],
#  ['Alabama St.', 'NIT', 1.0],
#  ['Eastern Michigan', 'NIT', 1.0],
#  ['Southern Indiana', 'NIT', 0.99],
#  ['Navy', 'NIT', 0.99],
#  ['NJIT', 'NIT', 1.0],
#  ['Hampton', 'NIT', 1.0],
#  ['New Orleans', 'NIT', 1.0],
#  ['Dartmouth', 'NIT', 1.0],
#  ['Arkansas Pine Bluff', 'NIT', 1.0],
#  ['UT Rio Grande Valley', 'NIT', 0.99],
#  ['Alabama A&M', 'NIT', 1.0],
#  ['Morgan St.', 'NIT', 1.0],
#  ['Manhattan', 'NIT', 1.0],
#  ['Fairleigh Dickinson', 'NIT', 1.0],
#  ['Central Arkansas', 'NIT', 1.0],
#  ['Texas A&M Commerce', 'NIT', 1.0],
#  ['Cal Poly', 'NIT', 1.0],
#  ['North Carolina A&T', 'NIT', 1.0],
#  ['LIU Brooklyn', 'NIT', 1.0],
#  ['Loyola MD', 'NIT', 0.99],
#  ['Army', 'NIT', 0.99],
#  ['Buffalo', 'NIT', 1.0],
#  ['Incarnate Word', 'NIT', 1.0],
#  ['Florida A&M', 'NIT', 1.0],
#  ['Tennessee Tech', 'NIT', 1.0],
#  ['Detroit', 'NIT', 1.0],
#  ['Prairie View A&M', 'NIT', 1.0],
#  ['Holy Cross', 'NIT', 1.0],
#  ['Maryland Eastern Shore', 'NIT', 1.0],
#  ['Pacific', 'NIT', 1.0],
#  ['Houston Christian', 'NIT', 1.0],
#  ['Southeast Missouri St.', 'NIT', 1.0],
#  ['Lindenwood', 'NIT', 1.0],
#  ['Siena', 'NIT', 1.0],
#  ['VMI', 'NIT', 1.0],
#  ['Stonehill', 'NIT', 1.0],
#  ['St. Francis PA', 'NIT', 1.0],
#  ['IUPUI', 'NIT', 1.0],
#  ['Coppin St.', 'NIT', 1.0],
#  ['Mississippi Valley St.', 'NIT', 1.0]]
